# %% [markdown]
# <a href="https://colab.research.google.com/github/eodus9590/daeyeon/blob/master/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EA%B8%B0%EC%88%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 인공지능 4가지 기술들

# %% [markdown]
# <인공지능 4가지 리스트>

# %% [markdown]
# * 알파고

# %% [markdown]
# * 자율주행

# %% [markdown]
# * 인공지능 스피커

# %% [markdown]
# * 파파고

# %% [markdown]
# ---------------------------------------------------------

# %% [markdown]
# ## 1. 알파고

# %% [markdown]
# **알파고?**
#
#  알파벳의 구글 딥마인드에서 개발한 바둑 인공지능 프로그램입니다. 알파고는 세 가지 인공지능 구조를 혼합하여 동작되어 있습니다. 가치망, 정책망, 몬테 카를로 트리 검색 세가지로 구성되어 있으며 다양한 수를 따져보는 인공지능 기능이 있으며 무려 1202개 cpu와 176개 GPU로 구성되어 있습니다.

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 기능 실행

for fn in uploaded.keys(): # 업로드된 파일 정보 출력
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d1d71bb9-5e2e-48bb-b9c7-ea29ec3db875" name="files[]" multiple disabled />
#      <output id="result-d1d71bb9-5e2e-48bb-b9c7-ea29ec3db875">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 알파고.jpg to 알파고.jpg
# User uploaded file "알파고.jpg" with length 455727 bytes

# %%
from IPython.display import Image
Image('알파고.jpg')

# %% [markdown]
# ## 2. 자율주행

# %% [markdown]
# **자율주행?**
#
#  자율주행은 무생물인 교통수단이 사람 없이 스스로 판단하고 운행하는 것을 뜻한다. 무인운전과 혼용되어 쓰이기도 하나 엄밀히는 차이가 있다. 무인운전은 해당 운송 수단 내에 사람만 없지 엄연히 외부의 명령에 의해 통제받아 주행하는 것이지만 자율주행은 사람에 의해 통제받지 않고 탑재된 인공지능 컴퓨터가 스스로 판단하여 주행하는 것이다.

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 기능 실행

for fn in uploaded.keys(): # 업로드된 파일 정보 출력
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fd44993d-1bad-435e-a3e8-e0d06f24bc68" name="files[]" multiple disabled />
#      <output id="result-fd44993d-1bad-435e-a3e8-e0d06f24bc68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 자율주행.jpg to 자율주행.jpg
# User uploaded file "자율주행.jpg" with length 95086 bytes

# %%
from IPython.display import Image
Image('자율주행.jpg')

# %% [markdown]
# ## 3. 인공지능 스피커

# %% [markdown]
# **인공지능 스피커?**
#
# AI 스피커는 인공지능 알고리즘을 이용해 사용자와 음성으로 의사소통을 한다. AI 스피커를 이용하면 음성인식을 통해 집안의 기기를 목소리만으로 간편하게 제어하는 식으로 손쉽게 스마트홈 환경을 구축할 수 있다. 또한 터치 기반과 달리 음성 기반 조작은 쉽게 배우고 사용할 수 있다. 우리가 스마트폰에서 ‘시리’나 ‘S보이스’ 등을 이용해 기기를 제어하는 게 낯설지 않듯, 음성인식 기반 UI 플랫폼은 우리 생활 가까이에 숨어 있다.

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 기능 실행

for fn in uploaded.keys(): # 업로드된 파일 정보 출력
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f98c5619-12ab-4a9e-8562-437375dc39f5" name="files[]" multiple disabled />
#      <output id="result-f98c5619-12ab-4a9e-8562-437375dc39f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 인공지능스피커.jpg to 인공지능스피커.jpg
# User uploaded file "인공지능스피커.jpg" with length 37617 bytes

# %%
from IPython.display import Image
Image('인공지능스피커.jpg')

# %% [markdown]
# ## 4. 파파고

# %% [markdown]
# **파파고?**
#
# 파파고는 네이버 랩에서 자체 개발한 인공신경막 기반 AI 기술입니다. 언어는  한국어, 일본어, 중국어, 영어, 스페인어, 프랑스어, 베트남어, 태국어, 인도네시아어, 독일어, 러시아어, 포르투갈어, 힌디어 13개 등의 언어를 번역 할 수 있습니다. 기능에서는 1:1대화 모드, 이미지 번역, WSD 화면, 환율 자동 변환, 글로벌 회화 등 다양한 딥러닝 기술로 통해 회화를 편하게 해주는 인공지능 번역 기술입니다.

# %%
from google.colab import files
uploaded = files.upload() # 파일 업로드 기능 실행

for fn in uploaded.keys(): # 업로드된 파일 정보 출력
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9efb2aab-1d95-43af-b74d-4e5d4e84a5df" name="files[]" multiple disabled />
#      <output id="result-9efb2aab-1d95-43af-b74d-4e5d4e84a5df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 파파고.jpg to 파파고.jpg
# User uploaded file "파파고.jpg" with length 35830 bytes

# %%
from IPython.display import Image
Image('파파고.jpg')
